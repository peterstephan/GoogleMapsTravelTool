# %%
import travel_tool # import and run 'travel_tool.py'
# Out:
# +ACACIA+RIDGE+QLD+4110+Australia
# +Brisbane+CBD+QLD+4000+Australia
# 1970-01-01 00:00:00
# 2021-09-15 07:00:00
# 1631689200
# https://maps.googleapis.com/maps/api/distancematrix/xml?origins=+ACACIA+RIDGE+QLD+4110+Australia&destinations=+Brisbane+CBD+QLD+4000+Australia&units=metric&language=en-EN&mode=driving&transit_mode=&transit_routing_preference=&avoid=&departure_time=1631689200&traffic_model=best_guess&key=AIzaSyDF1c2I4QHUc7E0Kt8k0gPTO3R8gxo-jJ8
#
# <?xml version="1.0" encoding="utf-8"?>
# <DistanceMatrixResponse>
# <status>OK</status>
# <origin_address>Acacia Ridge QLD 4110, Australia</origin_address>
# <destination_address>Brisbane City QLD 4000, Australia</destination_address>
# <row>
# <element>
# <status>OK</status>
# <duration>
# <value>1351</value>
# <text>23 mins</text>
# </duration>
# <distance>
# <value>17460</value>
# <text>17.5 km</text>
# </distance>
# <duration_in_traffic>
# <value>1647</value>
# <text>27 mins</text>
# </duration_in_traffic>
# </element>
# </row>
# ...
